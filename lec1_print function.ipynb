# %%
print("hello world")# print function applied on text
# Out:
# hello world

# %%
print(2) #nums
# Out:
# 2

# %%
print(2.4) #decimal
# Out:
# 2.4

# %%
print("false") #bolian
# Out:
# false

# %%
print("USA", "Europe","pakistan", "Gulf")
# Out:
# USA Europe pakistan Gulf

# %%
print("pakistan", 11, True)
# Out:
# pakistan 11 True

# %%
print()

# %%
print("USA", "Europe","pakistan", "Gulf", sep="/")
# Out:
# USA/Europe/pakistan/Gulf

# %%
print("USA", "Europe","pakistan", "Gulf", sep="-")
# Out:
# USA-Europe-pakistan-Gulf

# %%
print("USA", "Europe","pakistan", "Gulf", sep="----")
# Out:
# USA----Europe----pakistan----Gulf

# %%
print("USA", "Europe","pakistan", "Gulf", sep=",,,,,")
# Out:
# USA,,,,,Europe,,,,,pakistan,,,,,Gulf

# %%
print("USA", "Europe","pakistan", "Gulf", sep="###")
# Out:
# USA###Europe###pakistan###Gulf

# %%
print("USA", "Europe","pakistan", "Gulf", end="/n")
# Out:
# USA Europe pakistan Gulf/n
