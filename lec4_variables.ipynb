# %%
# python is smart enough to understand the data type n is call dynamic typing
# we dont need to declair the variable
name = "Ahmad"

# %%
print(name)
# Out:
# Ahmad

# %%
# we can change the variable value
name = "hello world"
name
# Out:
# 'hello world'

# %%
# dynamic binding: it is python's feature in wich one variable can store multiple data types
# static binding: in other languages variable can store one data type

# %%
# special syntax
a =2;b=3;c=4
print(a)
print(b)
print(c)
# Out:
# 2
# 3
# 4

# %%
a,b,c = 2,3,4
print(a)
print(b)
print(c)
# Out:
# 2
# 3
# 4

# %%
a =b =c =5
print(a)
print(b)
print(c)
# Out:
# 5
# 5
# 5
