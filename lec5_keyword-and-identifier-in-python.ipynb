# %% [markdown]
# keywords: python is a case sencitive language
# in programming a key word is a word that is reserved by the proggrame because the word has the special meanings.
# keywords can be commands or parameters.
# every programming language has a set of keywords that can not be used as variables.

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# almost 33 keywords are there in python

# %% [markdown]
# identifier: it is a name used to identify the variable, function, class and other objects
# rules for setting identifiers
#
# 1.can only start with an alphabet or _
#
# 2.followed by 0 or more letter, _ and digits.
#
# 3.keywords can not be used as an identifires

# %%
name='ahmad' # alphabets can be a variable name
print(name)
# Out:
# ahmad

# %%
_ ='ali' # underscore can be a variable name
print(_)
# Out:
# ali

# %%
2 = 'akbar' # a digit can not be variable name
print(2)
# Out:
#   Cell In[5], line 1
#     2 = 'akbar'
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
name1 = 'hira'
print(name1)
# Out:
# hira
